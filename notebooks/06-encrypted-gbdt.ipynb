# %% [markdown]
# # 06 Encrypted Gbdt\n\nStarter notebook for `privacy-preserving-ml`.\nUse this notebook to expand experiment tracking, visualizations, and reproducible analysis.\n

# %%
from pathlib import Path\n\nproject_root = Path.cwd()\nproject_root\n
